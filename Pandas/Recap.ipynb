# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data = [
    ['Tiger', 'South East Asia', 'Mammals'],
    ['Whales', 'Pacific Ocean', 'Mammals'],
    ['Anaconda', 'Amazon', 'Reptiles']
]
df = pd.DataFrame(data, columns=['Col1', 'Col2', 'Col3'])
df
# Out:
#        Col1             Col2      Col3
# 0     Tiger  South East Asia   Mammals
# 1    Whales    Pacific Ocean   Mammals
# 2  Anaconda           Amazon  Reptiles

# %%
df = pd.DataFrame({
    'name' : ['Alex', 'Bob', 'Cleopetra'],
    'gender' : ['M', 'M', 'F'],
    'yob': [2000, 2001, 2000]
})

df
# Out:
#         name gender   yob
# 0       Alex      M  2000
# 1        Bob      M  2001
# 2  Cleopetra      F  2000

# %%
df.sample(2)
# Out:
#    name gender   yob
# 1   Bob      M  2001
# 0  Alex      M  2000

# %%
titanic = pd.read_csv('titanic.csv', header=0, encoding='UTF-8')
#cchardet

# %%
titanic.head(2)
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Survived
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S         0
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C         1

# %%
# pd.read_excel("...", sheet_name="")

# %%
taxi = sns.load_dataset("taxis")
taxi.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
taxi.shape
# Out:
# (6433, 14)

# %%
taxi.shape[0], taxi.shape[1]
# Out:
# (6433, 14)

# %%
taxi.size
# Out:
# 90062

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Name', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Name            object
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Survived         int64
# dtype: object

# %%
titanic.Age.dtype
# Out:
# dtype('float64')

# %%
titanic = titanic.replace('', np.nan)
titanic = titanic.replace(' ', np.nan)
titanic.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
titanic.columns[titanic.isnull().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic[titanic.isna().any(axis=1)].head(10)
# Out:
#     PassengerId                                               Name  Pclass  \
# 0             1                            Braund, Mr. Owen Harris       3
# 2             3                             Heikkinen, Miss. Laina       3
# 4             5                           Allen, Mr. William Henry       3
# 5             6                                   Moran, Mr. James       3
# 7             8                     Palsson, Master. Gosta Leonard       3
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)       2
# 12           13                     Saundercock, Mr. William Henry       3
# 13           14                        Andersson, Mr. Anders Johan       3
# 14           15               Vestrom, Miss. Hulda Amanda Adolfina       3
#
#        Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
titanic[titanic.Age.isna()].head()
# Out:
#     PassengerId                           Name  Pclass     Sex  Age  SibSp  \
# 5             6               Moran, Mr. James       3    male  NaN      0
# 17           18   Williams, Mr. Charles Eugene       2    male  NaN      0
# 19           20        Masselmani, Mrs. Fatima       3  female  NaN      0
# 26           27        Emir, Mr. Farred Chehab       3    male  NaN      0
# 28           29  O'Dwyer, Miss. Ellen "Nellie"       3  female  NaN      0
#
#     Parch  Ticket     Fare Cabin Embarked  Survived
# 5       0  330877   8.4583   NaN        Q         0
# 17      0  244373  13.0000   NaN        S         1
# 19      0    2649   7.2250   NaN        C         1
# 26      0    2631   7.2250   NaN        C         0
# 28      0  330959   7.8792   NaN        Q         1

# %%
titanic[~titanic.isna().any(axis=1)].head(10)
# Out:
#     PassengerId                                               Name  Pclass  \
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 6             7                            McCarthy, Mr. Timothy J       1
# 10           11                    Sandstrom, Miss. Marguerite Rut       3
# 11           12                           Bonnell, Miss. Elizabeth       1
# 21           22                              Beesley, Mr. Lawrence       2
# 23           24                       Sloper, Mr. William Thompson       1
# 27           28                     Fortune, Mr. Charles Alexander       1
# 52           53           Harper, Mrs. Henry Sleeper (Myna Haxtun)       1
# 54           55                     Ostby, Mr. Engelhart Cornelius       1
#
#        Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %%
titanic['Age'].fillna(titanic['Age'].median(skipna=True), inplace=True)

# %%
titanic[titanic.Age.isna()].head()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Name, Pclass, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Survived]
# Index: []

# %%
titanic.drop_duplicates(inplace=True)

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic['Embarked'].nunique()
# Out:
# 3

# %%
titanic.head(7)
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
# 5            6                                   Moran, Mr. James       3
# 6            7                            McCarthy, Mr. Timothy J       1
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# ...

# %%
titanic.loc[4:6,['PassengerId','Age', 'Fare', 'Ticket']].head(3)
# Out:
#    PassengerId   Age     Fare  Ticket
# 4            5  35.0   8.0500  373450
# 5            6  28.0   8.4583  330877
# 6            7  54.0  51.8625   17463

# %%
titanic.iloc[4:6, 0:4].head(3)
# Out:
#    PassengerId                      Name  Pclass   Sex
# 4            5  Allen, Mr. William Henry       3  male
# 5            6          Moran, Mr. James       3  male

# %%
titanic[['PassengerId','Age', 'Fare', 'Ticket']].head()
# Out:
#    PassengerId   Age     Fare            Ticket
# 0            1  22.0   7.2500         A/5 21171
# 1            2  38.0  71.2833          PC 17599
# 2            3  26.0   7.9250  STON/O2. 3101282
# 3            4  35.0  53.1000            113803
# 4            5  35.0   8.0500            373450

# %%
titanic['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
titanic.columns = ['PassengerId', 'Name', 'Pclass', 'Gender', 'Age', 'SibSp', 'Parch',
       'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived']

# %%
titanic.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#    Gender   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
